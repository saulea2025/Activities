# %% [markdown]
# <a href="https://colab.research.google.com/github/saulea2025/Activities/blob/master/Repl0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local/miniconda
# Out:
# --2025-01-23 19:22:11--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 147784736 (141M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh.1’
#
# Miniconda3-latest-L 100%[===================>] 140.94M   110MB/s    in 1.3s
#
# 2025-01-23 19:22:13 (110 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh.1’ saved [147784736/147784736]
#
# PREFIX=/usr/local/miniconda
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.

# %%
import sys
sys.path.append('/usr/local/miniconda/bin')

# %%
# !echo ". /usr/local/miniconda/etc/profile.d/conda.sh" >> ~/.bashrc
# !source ~/.bashrc

# %%
# !conda --version
# Out:
# conda 24.11.1

# %%
import os
os.environ['PATH'] = '/usr/local/miniconda/bin:' + os.environ['PATH']

# %%
# !conda create -p /usr/local/miniconda/envs/mooddrift -c ejolly -c conda-forge \
    python=3.8.8 numpy=1.19.2 pandas=1.1.5 pytest=6.2.2 joblib=1.0.1 rpy2=3.4.3 \
    matplotlib=3.3.4 seaborn=0.11.1 scikit-learn=0.24.1 numexpr=2.7.3 patsy=0.5.1 \
    statsmodels=0.12.2 openpyxl=3.0.7 pymer4=0.7.3 r-psych=2.1.3 xlrd=2.0.1 \
    r-mumin=1.43.17 -y
# Out:
# Channels:
#  - ejolly
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda/envs/mooddrift
#
#   added / updated specs:
#     - joblib=1.0.1
#     - matplotlib=3.3.4
#     - numexpr=2.7.3
#     - numpy=1.19.2
#     - openpyxl=3.0.7
#     - pandas=1.1.5
#     - patsy=0.5.1
#     - pymer4=0.7.3
#     - pytest=6.2.2
#     - python=3.8.8
#     - r-mumin=1.43.17
#     - r-psych=2.1.3
#     - rpy2=3.4.3
#     - scikit-learn=0.24.1
#     - seaborn=0.11.1
#     - statsmodels=0.12.2
#     - xlrd=2.0.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
# ...

# %%
# !conda run -n mooddrift git clone https://github.com/djangraw/MoodDrift.git
# Out:
# fatal: destination path 'MoodDrift' already exists and is not an empty directory.
#
# ERROR conda.cli.main_run:execute(125): `conda run git clone https://github.com/djangraw/MoodDrift.git` failed. (See above for error)

# %%
# %cd MoodDrift
# Out:
# /content/MoodDrift

# %%
# !conda run -n mooddrift pip install -e .
# Out:
# Obtaining file:///content/MoodDrift
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py develop for MoodDrift
# ...
#
#   DEPRECATION: Legacy editable install of MoodDrift==0.0.1 from file:///content/MoodDrift (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457

# %%
from google.colab import drive
drive.mount('/content/drive')
